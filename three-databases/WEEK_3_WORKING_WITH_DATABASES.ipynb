# %% [markdown]
# <a href="https://colab.research.google.com/github/Tim-ber6/COMP-593-2021/blob/main/three-databases/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
# myConnection.commit()
# myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-03-03 20:29:44.245559',
#   '2022-03-03 20:29:44.245567',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-13.3.0-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 6.4 MB/s
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)
# Installing collected packages: faker
# Successfully installed faker-13.3.0

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {} ||'.format( fake.name(), fake.job() ) )
# Out:
# Shawn Barrera || Community education officer ||
# Margaret Cabrera || Scientist, biomedical ||
# Taylor Romero || Lecturer, further education ||
# Ronald Thomas || Chartered loss adjuster ||
# Linda Ford || Sales promotion account executive ||
# Jerry Perez || Tour manager ||
# David Manning || Communications engineer ||
# Lisa Smith || Fisheries officer ||
# Caitlin Flowers || Statistician ||
# Nancy Davis || Fish farm manager ||

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker()


for _ in range(1000):
  myPerson = (fake.name(), 
            fake.email(), 
            fake.address(), 
            fake.city(), 
            fake.state(), 
            fake.country(), 
            fake.phone_number(), 
            fake.sentence(nb_words=10),
            "1967-09-12",
            fake.random_int(min=999, max=2500),
            datetime.now(), 
            datetime.now(),
            fake.ipv4())
  myCursor.execute(addPersonQuery, myPerson)
  myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

myConnection.commit()
myConnection.close()
#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
# Out:
# Streaming output truncated to the last 5000 lines.
#   2487,
#   '2022-03-03 20:29:51.167751',
#   '2022-03-03 20:29:51.167754',
#   '42.134.160.30'),
#  (650,
#   'Christina Ewing',
#   'mikayla04@example.org',
#   '4582 Weiss Neck\nBryantmouth, MI 92022',
#   'South Peggyburgh',
#   'Washington',
#   'Lebanon',
#   '001-545-812-8285x0144',
#   'Appear appear easy his measure bed young issue now shake throughout '
#   'continue listen.',
#   '1967-09-12',
#   1182,
#   '2022-03-03 20:29:51.168555',
#   '2022-03-03 20:29:51.168560',
#   '153.39.199.189'),
#  (651,
#   'Rebecca Alvarado',
#   'jameslong@example.com',
#   '486 Brooke Plains\nSouth Heatherburgh, CA 55848',
#   'North Eric',
#   'Arkansas',
#   'Cuba',
#   '(558)047-4709',
#   'Writer mean western paper police property.',
#   '1967-09-12',
#   2140,
#   '2022-03-03 20:29:51.169366',
#   '2022-03-03 20:29:51.169369',
#   '110.251.86.196'),
#  (652,
#   'Mr. Eric Liu MD',
#   'john13@example.net',
#   '3598 Joseph Estates\nCampbellfurt, OR 01169',
#   'Smithmouth',
#   'Michigan',
#   'Hong Kong',
#   '001-066-124-1368',
#   'Easy during bit out art offer south return author resource oil.',
#   '1967-09-12',
#   1876,
#   '2022-03-03 20:29:51.170171',
#   '2022-03-03 20:29:51.170174',
#   '140.55.200.218'),
#  (653,
#   'Michelle Marshall',
#   'vbowman@example.net',
#   '4903 Figueroa Trafficway\nSimpsonstad, NH 74527',
#   'Brooksview',
#   'Tennessee',
#   'Iraq',
#   '677-180-1223x237',
#   'Record line notice control increase long tend customer power.',
#   '1967-09-12',
#   2040,
#   '2022-03-03 20:29:51.171147',
#   '2022-03-03 20:29:51.171153',
#   '135.93.178.62'),
#  (654,
#   'Reginald Gregory',
#   'whorne@example.com',
#   '529 Collins Circle Suite 109\nLake Tylerborough, OH 18492',
#   'West Sethborough',
#   'Virginia',
#   'Gabon',
#   '(623)106-6920',
#   'Wait message perform exist test wear rather generation.',
#   '1967-09-12',
#   2291,
#   '2022-03-03 20:29:51.172573',
#   '2022-03-03 20:29:51.172579',
#   '145.31.215.101'),
#  (655,
#   'Randy Brown',
#   'wpeterson@example.org',
#   '41204 Hailey Courts\nPort Davidbury, NY 05936',
#   'East Dawn',
#   'Delaware',
#   'Haiti',
#   '(604)837-7675x37499',
#   'South century piece example do third charge senior toward yeah voice '
#   'brother stand.',
#   '1967-09-12',
#   1229,
#   '2022-03-03 20:29:51.173979',
#   '2022-03-03 20:29:51.173984',
#   '2.170.19.130'),
#  (656,
#   'Erica Wallace',
#   'carla87@example.com',
#   '02924 Hopkins Glen Apt. 786\nEast Jamesmouth, RI 19453',
#   'Chanview',
#   'Louisiana',
#   'Martinique',
#   '(127)726-7325',
#   'Of unit race major loss garden address spring.',
#   '1967-09-12',
#   2369,
#   '2022-03-03 20:29:51.174810',
#   '2022-03-03 20:29:51.174814',
#   '117.144.198.231'),
#  (657,
#   'Tammy Collins',
#   'charles68@example.net',
#   '15599 Moore Tunnel\nNew Robertborough, MO 60918',
#   'Port Elijah',
#   'Nevada',
#   'Libyan Arab Jamahiriya',
#   '001-705-940-7886x02861',
#   'Shoulder industry morning modern show peace civil book class state employee '
#   'care institution.',
#   '1967-09-12',
#   1798,
#   '2022-03-03 20:29:51.175654',
#   '2022-03-03 20:29:51.175658',
#   '178.111.120.155'),
#  (658,
#   'Jenna Miller',
#   'shanerose@example.org',
#   '762 Brown Rest Suite 863\nNorth Kathrynville, NC 36308',
#   'West Anna',
#   'Ohio',
#   'Cameroon',
#   '742-508-8639x9549',
#   'Third face subject list decade development Democrat culture.',
#   '1967-09-12',
#   1515,
#   '2022-03-03 20:29:51.176520',
#   '2022-03-03 20:29:51.176524',
#   '188.88.11.159'),
#  (659,
#   'Yvonne Harris',
#   'yevans@example.com',
#   '247 Green Creek\nNorth Jeffrey, MI 64113',
#   'Robertbury',
#   'Connecticut',
#   'Sweden',
#   '9006354669',
#   'Above hot other above give window fine.',
#   '1967-09-12',
#   1009,
#   '2022-03-03 20:29:51.177305',
#   '2022-03-03 20:29:51.177309',
#   '201.92.144.35'),
#  (660,
#   'Paul Smith',
#   'kspears@example.org',
#   '67119 Heidi Brooks Suite 794\nWest Sherryland, IL 87289',
#   'Leonardmouth',
#   'Georgia',
#   'Vietnam',
#   '(486)043-5053',
#   'Also watch general would science price lawyer job book lot air plan though '
#   'blood.',
#   '1967-09-12',
#   1381,
#   '2022-03-03 20:29:51.178101',
#   '2022-03-03 20:29:51.178104',
#   '45.170.110.152'),
#  (661,
#   'Rachel Evans',
#   'jose12@example.com',
#   '494 Anthony Drives\nSouth Christopherborough, AR 04937',
#   'Dyerport',
#   'New Mexico',
#   'Montserrat',
#   '(760)795-1998x266',
#   'Show rise build conference just wear skin.',
#   '1967-09-12',
#   1431,
#   '2022-03-03 20:29:51.178842',
#   '2022-03-03 20:29:51.178845',
#   '48.58.233.249'),
#  (662,
#   'Sheila Rodriguez',
#   'curtislam@example.org',
#   '71645 Davis Creek\nNorth Jennifer, KY 10203',
#   'Port Marc',
#   'Kansas',
#   'Equatorial Guinea',
#   '+1-449-529-1005',
#   'One low feeling student station eight along hear level measure red occur '
#   'over.',
#   '1967-09-12',
#   2296,
#   '2022-03-03 20:29:51.179636',
#   '2022-03-03 20:29:51.179639',
#   '144.91.145.2'),
#  (663,
#   'Nancy Williams',
#   'miranda84@example.com',
#   '765 Mcdonald Lakes Suite 470\nPort Brianchester, WV 85543',
#   'North Jeffery',
#   'South Dakota',
#   'South Georgia and the South Sandwich Islands',
#   '001-614-898-7073x01047',
#   'Human single drive culture agent risk others tell fight decision over '
#   'worker.',
#   '1967-09-12',
#   1848,
#   '2022-03-03 20:29:51.180391',
#   '2022-03-03 20:29:51.180394',
#   '110.56.50.209'),
#  (664,
#   'John Hampton',
#   'ochoi@example.net',
#   '1323 Theresa Cape\nAguilarberg, AK 01786',
#   'Lake Larry',
#   'Maine',
#   'Zimbabwe',
#   '(906)155-3451',
#   'Some reduce coach step country drive exist simply government big turn.',
#   '1967-09-12',
#   1194,
#   '2022-03-03 20:29:51.181149',
#   '2022-03-03 20:29:51.181152',
#   '132.161.208.180'),
#  (665,
#   'Teresa Smith',
#   'smithricky@example.net',
#   '2069 Rachel Ranch\nLloydchester, OK 82916',
#   'West Lee',
#   'Idaho',
#   'Saint Helena',
#   '183-544-9308',
#   'Budget fire prevent in that finally when how him standard including.',
#   '1967-09-12',
#   2092,
#   '2022-03-03 20:29:51.182221',
#   '2022-03-03 20:29:51.182227',
#   '120.112.61.254'),
#  (666,
#   'Maria Mendoza',
#   'carternathan@example.com',
#   '196 Diane Lane\nPort Nicolemouth, MN 82159',
#   'North Patrickton',
#   'North Carolina',
#   'Seychelles',
#   '2139594293',
#   'Enough bill myself himself year goal group.',
#   '1967-09-12',
#   2307,
#   '2022-03-03 20:29:51.183155',
#   '2022-03-03 20:29:51.183160',
#   '58.66.49.33'),
#  (667,
#   'Patrick Maxwell',
#   'cooperjerry@example.com',
#   '710 Flynn Walk\nPort Carol, GA 84471',
#   'Evansville',
#   'Ohio',
#   "Lao People's Democratic Republic",
#   '043-030-2606x3005',
#   'Laugh late wait only item stop ask offer natural serve those social.',
#   '1967-09-12',
#   1246,
#   '2022-03-03 20:29:51.184334',
#   '2022-03-03 20:29:51.184340',
#   '23.231.153.237'),
#  (668,
#   'Ashley Martinez',
#   'barrettbrian@example.net',
#   '4727 Michelle Islands\nLoweville, CT 51113',
#   'New Seanside',
#   'Oklahoma',
#   'Korea',
#   '001-991-994-2916',
#   'Sign media suffer his table like argue cultural.',
#   '1967-09-12',
#   1768,
#   '2022-03-03 20:29:51.185237',
#   '2022-03-03 20:29:51.185241',
#   '85.129.188.90'),
#  (669,
#   'Robert Johnson',
#   'matthew03@example.com',
#   '641 Amy Estate\nLeetown, OK 41388',
#   'Stevenburgh',
#   'Washington',
#   'Croatia',
#   '491-092-6584x484',
#   'Someone impact where of staff choose spend tree share position majority.',
#   '1967-09-12',
#   1699,
#   '2022-03-03 20:29:51.186012',
#   '2022-03-03 20:29:51.186016',
#   '83.78.222.108'),
#  (670,
#   'Jerry Taylor',
#   'mfrancis@example.org',
#   'Unit 1642 Box 8360\nDPO AA 15850',
#   'Sloanhaven',
#   'Michigan',
#   'United States Virgin Islands',
#   '(270)822-9672x79756',
#   'Board computer remember usually never although however past good while '
#   'parent your.',
#   '1967-09-12',
#   1341,
#   '2022-03-03 20:29:51.186753',
#   '2022-03-03 20:29:51.186758',
#   '48.46.142.155'),
#  (671,
#   'Bryan Gardner',
#   'taylorjessica@example.com',
#   '7923 Jonathan Ville\nKarenview, AK 69092',
#   'Adamsport',
#   'Virginia',
#   'Guam',
#   '908.883.3868x5314',
#   'Community Mrs fact fine boy start bank show beat forget role respond '
#   'imagine.',
#   '1967-09-12',
#   2063,
#   '2022-03-03 20:29:51.187825',
#   '2022-03-03 20:29:51.187830',
#   '136.233.158.92'),
#  (672,
#   'Teresa Gardner',
#   'mezateresa@example.net',
#   '3789 Luis Drives Suite 669\nNorth Michelle, DE 11978',
#   'Lake Danaport',
#   'Oregon',
#   'Turkmenistan',
#   '557-495-4182',
#   'Treatment group model their message hard she like day.',
#   '1967-09-12',
#   2309,
#   '2022-03-03 20:29:51.188769',
#   '2022-03-03 20:29:51.188773',
#   '198.246.212.9'),
#  (673,
#   'Sabrina Jones',
#   'swhite@example.org',
#   '38792 Zachary Causeway Apt. 866\nStricklandfort, WA 90255',
#   'North Shannon',
#   'Arizona',
#   'Liberia',
#   '+1-608-341-4261x4770',
#   'Leave over surface save there research teach stage rather.',
#   '1967-09-12',
#   1332,
#   '2022-03-03 20:29:51.189625',
#   '2022-03-03 20:29:51.189629',
#   '15.237.125.157'),
#  (674,
#   'Jody Ball',
#   'arosario@example.org',
#   '8246 Mark Drive Apt. 179\nKathrynmouth, VA 46712',
#   'Bakerberg',
#   'Kansas',
#   'Haiti',
#   '963.301.6066x464',
#   'Enough hope our artist cup girl scientist only become.',
#   '1967-09-12',
#   1667,
#   '2022-03-03 20:29:51.190457',
#   '2022-03-03 20:29:51.190460',
#   '15.7.140.79'),
#  (675,
#   'Elizabeth Tate',
#   'matthewharris@example.net',
#   '315 Harvey Haven Suite 265\nAngelaville, IL 64119',
#   'Jessicabury',
#   'Arizona',
#   'Gabon',
#   '001-503-667-7112x6814',
#   'Hundred remember side soldier lose report high.',
#   '1967-09-12',
#   1606,
#   '2022-03-03 20:29:51.191313',
#   '2022-03-03 20:29:51.191317',
#   '53.244.188.255'),
#  (676,
#   'Robin Duke',
#   'whitefrederick@example.net',
#   '97208 Lori Ranch Suite 702\nPort Karen, MI 44465',
#   'North Chloeburgh',
#   'Indiana',
#   'Georgia',
#   '001-800-439-2530x97108',
#   'Yard inside lose task learn matter hospital way.',
#   '1967-09-12',
#   2347,
#   '2022-03-03 20:29:51.192159',
#   '2022-03-03 20:29:51.192163',
#   '94.179.226.181'),
#  (677,
#   'Peter Rice',
#   'kpowell@example.com',
#   '4018 Diane Via\nGonzalezland, ME 92444',
#   'Adamborough',
#   'Massachusetts',
#   'Martinique',
#   '001-134-089-4521x54451',
#   'Out thank also hundred example late campaign three within.',
#   '1967-09-12',
#   1628,
#   '2022-03-03 20:29:51.192925',
#   '2022-03-03 20:29:51.192929',
#   '120.152.212.87'),
#  (678,
#   'Frederick Williams',
#   'spencershelley@example.net',
#   '545 Jones Prairie\nPort Keith, KY 35579',
#   'West James',
#   'West Virginia',
#   'Myanmar',
#   '698-897-4679x2248',
#   'Rise my evening call music power move degree discussion send continue court '
#   'night.',
#   '1967-09-12',
#   1513,
#   '2022-03-03 20:29:51.193773',
#   '2022-03-03 20:29:51.193776',
#   '138.74.96.184'),
#  (679,
#   'Lawrence Johnson',
#   'reneerichardson@example.net',
#   '157 Cooper Village\nMyerston, SC 60494',
#   'Gregoryview',
#   'Alaska',
#   'Anguilla',
#   '0349324064',
#   'Successful what which cold east why prevent red.',
#   '1967-09-12',
#   2390,
#   '2022-03-03 20:29:51.194631',
#   '2022-03-03 20:29:51.194635',
#   '133.234.229.145'),
#  (680,
#   'Charles Barrera',
#   'brent10@example.org',
#   '807 Paul Ridges\nEast Tonyastad, OK 42231',
#   'Brownside',
#   'Arizona',
#   'Maldives',
#   '001-551-824-4797x88797',
#   'Score including nor top charge themselves sister manage month.',
#   '1967-09-12',
#   1216,
#   '2022-03-03 20:29:51.195398',
#   '2022-03-03 20:29:51.195402',
#   '27.113.159.89'),
#  (681,
#   'Anna Murphy',
#   'alexli@example.net',
#   '49911 Miller Key\nSouth Gregoryburgh, IN 15039',
#   'Lisatown',
#   'Oklahoma',
#   'Saint Vincent and the Grenadines',
#   '001-125-096-1678x31446',
#   'Information protect return staff city cover reveal.',
#   '1967-09-12',
#   1097,
#   '2022-03-03 20:29:51.196245',
#   '2022-03-03 20:29:51.196250',
#   '44.160.2.98'),
#  (682,
#   'Julie Jones',
#   'victoriageorge@example.org',
#   '62464 Adkins Locks\nLaurahaven, HI 20394',
#   'Hooverview',
#   'Oregon',
#   'Saint Pierre and Miquelon',
#   '(190)725-1417x770',
#   'Magazine least technology camera national agreement oil audience play free '
#   'stand idea.',
#   '1967-09-12',
#   2343,
#   '2022-03-03 20:29:51.197126',
#   '2022-03-03 20:29:51.197130',
#   '140.236.216.156'),
#  (683,
#   'Bryan Collins',
#   'diane15@example.net',
#   '94746 Davis Turnpike\nPort Branditown, VA 20834',
#   'Lake Mitchell',
#   'North Dakota',
#   'Malta',
#   '(605)734-6348',
#   'Rule billion trouble same rate form report technology protect.',
#   '1967-09-12',
#   2078,
#   '2022-03-03 20:29:51.197871',
#   '2022-03-03 20:29:51.197875',
#   '83.90.92.111'),
#  (684,
#   'Steven Richards',
#   'ckelly@example.org',
#   '7311 Vance Bypass\nSouth Larrystad, NY 48589',
#   'West Davidstad',
#   'New Hampshire',
#   'Turks and Caicos Islands',
#   '(179)977-5748x08786',
#   'Interview according assume fill dark someone help sense.',
#   '1967-09-12',
#   1097,
#   '2022-03-03 20:29:51.198689',
#   '2022-03-03 20:29:51.198693',
#   '148.162.134.110'),
#  (685,
#   'Amy Avila',
#   'graydonna@example.com',
#   '58283 Charles Cliff Suite 384\nWisemouth, NY 31363',
#   'North Danielle',
#   'New Mexico',
#   'San Marino',
#   '+1-026-976-1588x329',
#   'Man send parent their well address character necessary world almost season.',
#   '1967-09-12',
#   2048,
#   '2022-03-03 20:29:51.199530',
#   '2022-03-03 20:29:51.199533',
#   '193.190.148.231'),
#  (686,
#   'Autumn Moon',
#   'maldonadotammy@example.org',
#   '36843 Parrish Landing Suite 764\nLake Justinburgh, MT 74577',
#   'East Karenmouth',
#   'Illinois',
#   'Lebanon',
#   '+1-819-540-4848',
#   'Factor collection apply pay center check shake seat amount short industry '
#   'to.',
#   '1967-09-12',
#   1174,
#   '2022-03-03 20:29:51.200377',
#   '2022-03-03 20:29:51.200380',
#   '58.250.76.56'),
#  (687,
#   'Jason Edwards',
#   'erikahernandez@example.com',
#   '9728 Tammy Forges Suite 185\nHughesmouth, AZ 51883',
#   'Henryhaven',
#   'Georgia',
#   'Peru',
#   '297.299.7721x523',
#   'That among hot bank try crime age.',
#   '1967-09-12',
#   1683,
#   '2022-03-03 20:29:51.201220',
#   '2022-03-03 20:29:51.201223',
#   '66.219.247.202'),
#  (688,
#   'Alicia Webb',
#   'michael15@example.org',
#   '4763 Danielle Track\nWest Judyhaven, MA 72829',
#   'Port Stefanieview',
#   'Arkansas',
#   'Taiwan',
#   '673.958.0555x465',
#   'Black general chair mouth win effort.',
#   '1967-09-12',
#   1769,
#   '2022-03-03 20:29:51.201989',
#   '2022-03-03 20:29:51.201993',
#   '34.16.163.222'),
#  (689,
#   'Sean Burns',
#   'pharvey@example.com',
#   '85939 Chad Drive\nPort Peterview, TX 68001',
#   'Taylorland',
#   'Oregon',
#   'Iraq',
#   '001-496-893-6783x077',
#   'Loss design glass century compare defense president color.',
#   '1967-09-12',
#   1346,
#   '2022-03-03 20:29:51.202812',
#   '2022-03-03 20:29:51.202817',
#   '39.195.123.110'),
#  (690,
#   'Michelle Coffey',
#   'washingtongary@example.org',
#   '00725 Baker Stream\nBernardfort, OK 75489',
#   'West Calvin',
#   'Nebraska',
#   'Japan',
#   '643-846-3788',
#   'Across music analysis common yeah air believe power professor military '
#   'heavy.',
#   '1967-09-12',
#   1455,
#   '2022-03-03 20:29:51.203821',
#   '2022-03-03 20:29:51.203825',
#   '100.215.198.61'),
#  (691,
#   'Melanie Norman',
#   'rjackson@example.net',
#   '92887 Richard Common Suite 949\nPetersonside, TX 15810',
#   'Wilsontown',
#   'Vermont',
#   'Mongolia',
#   '808-759-6784x2321',
#   'Fund bit house ability impact although final week.',
#   '1967-09-12',
#   2009,
#   '2022-03-03 20:29:51.204671',
#   '2022-03-03 20:29:51.204674',
#   '53.38.160.10'),
#  (692,
#   'Greg Williams',
#   'karenholland@example.com',
#   'USNS Stuart\nFPO AE 56794',
#   'Ricardochester',
#   'Massachusetts',
#   'Norway',
#   '+1-673-561-8625',
#   'Life individual less note time new machine year.',
#   '1967-09-12',
#   1645,
#   '2022-03-03 20:29:51.205387',
#   '2022-03-03 20:29:51.205391',
#   '207.164.139.160'),
#  (693,
#   'Sarah Bridges',
#   'jason74@example.org',
#   '0079 Sara Ferry Suite 914\nOliviamouth, WV 06128',
#   'Lake Victor',
#   'Kentucky',
#   'Seychelles',
#   '001-121-132-7738x156',
#   'Say difficult buy role certain market per public.',
#   '1967-09-12',
#   1447,
#   '2022-03-03 20:29:51.206149',
#   '2022-03-03 20:29:51.206153',
#   '31.233.89.72'),
#  (694,
#   'Johnny Underwood',
#   'qclark@example.org',
#   'USNV Black\nFPO AP 11375',
#   'Debraton',
#   'Vermont',
#   'Somalia',
#   '033-638-8305x580',
#   'Officer despite area market story across near.',
#   '1967-09-12',
#   2219,
#   '2022-03-03 20:29:51.206809',
#   '2022-03-03 20:29:51.206812',
#   '205.160.216.0'),
#  (695,
#   'Brittany Cherry',
#   'barrettruth@example.org',
#   'PSC 5264, Box 8932\nAPO AE 17641',
#   'Port April',
#   'Pennsylvania',
#   'Sweden',
#   '7554498887',
#   'Follow western outside whatever none almost several executive myself '
#   'knowledge.',
#   '1967-09-12',
#   1111,
#   '2022-03-03 20:29:51.207449',
#   '2022-03-03 20:29:51.207452',
#   '32.110.223.15'),
#  (696,
#   'Gloria George',
#   'waltersjennifer@example.net',
#   '6386 Michael Crossing Apt. 559\nLake Deannachester, FL 51188',
#   'New Kevin',
#   'Mississippi',
#   'Anguilla',
#   '001-825-438-5984x232',
#   'Enjoy environmental process project play newspaper.',
#   '1967-09-12',
#   2420,
#   '2022-03-03 20:29:51.208291',
#   '2022-03-03 20:29:51.208295',
#   '4.7.111.45'),
#  (697,
#   'Gary Romero',
#   'zchambers@example.com',
#   '64717 Shields Extensions Suite 678\nWest John, DE 23056',
#   'Russellton',
#   'New Mexico',
#   'Algeria',
#   '643-543-2847x829',
#   'Voice draw throughout wait street pattern raise into.',
#   '1967-09-12',
#   1714,
#   '2022-03-03 20:29:51.209142',
#   '2022-03-03 20:29:51.209146',
#   '138.238.124.187'),
#  (698,
#   'Kimberly Smith',
#   'meghan18@example.net',
#   '089 Patrick Fords\nSouth Coreyfort, WA 49789',
#   'Ritamouth',
#   'North Carolina',
#   'Greece',
#   '844-600-2527x37185',
#   'View sea unit research effect never entire in same rich whatever.',
#   '1967-09-12',
#   1342,
#   '2022-03-03 20:29:51.209861',
#   '2022-03-03 20:29:51.209865',
#   '102.37.198.88'),
#  (699,
#   'Danielle Harrison',
#   'wilkinschristopher@example.com',
#   '71367 Moore Branch\nRogersborough, MN 13720',
#   'Gonzalezborough',
#   'South Dakota',
#   'Maldives',
#   '001-592-166-5921x746',
#   'Decide bad six bed so among firm year.',
#   '1967-09-12',
#   2185,
#   '2022-03-03 20:29:51.210727',
#   '2022-03-03 20:29:51.210730',
#   '136.242.2.18'),
#  (700,
#   'Lisa Phillips',
#   'stephanietaylor@example.org',
#   '724 Ellis Summit Apt. 946\nSmithbury, CA 63697',
#   'South Donald',
#   'Oregon',
#   'Macedonia',
#   '001-510-520-0144x80700',
#   'Suffer physical room debate its speech field fine bed spring begin word '
#   'answer.',
#   '1967-09-12',
#   1827,
#   '2022-03-03 20:29:51.211582',
#   '2022-03-03 20:29:51.211585',
#   '209.170.103.70'),
#  (701,
#   'Marcus Johnson',
#   'elizabeth08@example.com',
#   '10272 Green Court\nPort Randy, AK 04663',
#   'North Jenna',
#   'Alabama',
#   'Nauru',
#   '968-315-5091',
#   'Program spend participant than morning have among easy animal produce.',
#   '1967-09-12',
#   1493,
#   '2022-03-03 20:29:51.212322',
#   '2022-03-03 20:29:51.212325',
#   '220.216.111.44'),
#  (702,
#   'Brandon Richardson',
#   'yprice@example.com',
#   '998 Cook Trail Apt. 381\nMichellemouth, PA 30282',
#   'North Melissa',
#   'Washington',
#   'Jersey',
#   '+1-149-075-6996',
#   'Success amount treatment alone produce cost result point spring science '
#   'enter themselves candidate.',
#   '1967-09-12',
#   1232,
#   '2022-03-03 20:29:51.213163',
#   '2022-03-03 20:29:51.213167',
#   '136.81.147.71'),
#  (703,
#   'Kelly Taylor',
#   'brent24@example.net',
#   '239 Lauren Squares\nLopezchester, IL 44178',
#   'Tonibury',
#   'North Dakota',
#   'Pakistan',
#   '287-202-3457x39309',
#   'Agent minute democratic challenge camera commercial.',
#   '1967-09-12',
#   2297,
#   '2022-03-03 20:29:51.213943',
#   '2022-03-03 20:29:51.213946',
#   '190.94.191.182'),
#  (704,
#   'Carol Rodriguez',
#   'jonathanjackson@example.net',
#   '57835 Lisa Forges Suite 814\nLake Deborahland, NV 12874',
#   'Mcdanielstad',
#   'Vermont',
#   'Saint Lucia',
#   '292-175-4830x9230',
#   'Far goal book around board prevent.',
#   '1967-09-12',
#   2269,
#   '2022-03-03 20:29:51.214785',
#   '2022-03-03 20:29:51.214788',
#   '104.220.156.138'),
#  (705,
#   'Peter Riley',
#   'cindy53@example.com',
#   '32891 Solis Fort Suite 969\nKellershire, IL 61455',
#   'New Ashley',
#   'North Dakota',
#   'American Samoa',
#   '(097)071-2139x2839',
#   'Summer design about issue list set else believe age without glass.',
#   '1967-09-12',
#   2396,
#   '2022-03-03 20:29:51.215571',
#   '2022-03-03 20:29:51.215575',
#   '114.110.101.119'),
#  (706,
#   'Angela Kaiser',
#   'burnsrobert@example.net',
#   '45786 Lopez Light Apt. 201\nSouth Pamela, NV 50144',
#   'Lake Peter',
#   'Oklahoma',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '(177)280-7802x538',
#   'Their style activity can share south drug.',
#   '1967-09-12',
#   1528,
#   '2022-03-03 20:29:51.216403',
#   '2022-03-03 20:29:51.216406',
#   '73.177.240.182'),
#  (707,
#   'Rebecca Lopez',
#   'kristen06@example.org',
#   '618 Jenkins Wall\nLynchstad, SC 93542',
#   'Dorothyland',
#   'New York',
#   'Mali',
#   '977-846-6277',
#   'Itself material democratic behavior cultural across.',
#   '1967-09-12',
#   1876,
#   '2022-03-03 20:29:51.217149',
#   '2022-03-03 20:29:51.217152',
#   '50.1.210.190'),
#  (708,
#   'Margaret Chapman',
#   'patrick24@example.org',
#   '043 Nguyen Highway\nJulieville, NY 34705',
#   'Huertaville',
#   'Virginia',
#   'Trinidad and Tobago',
#   '612.081.4147x34990',
#   'Indeed bank staff draw leader protect they.',
#   '1967-09-12',
#   2396,
#   '2022-03-03 20:29:51.217921',
#   '2022-03-03 20:29:51.217925',
#   '8.87.49.243'),
#  (709,
#   'Lisa Davis',
#   'richardwilliams@example.org',
#   '3017 Jennifer Courts\nRobinsonbury, NY 32814',
#   'East Jasonfort',
#   'Pennsylvania',
#   'Austria',
#   '001-153-156-7228',
#   'American coach writer do that general per on star make.',
#   '1967-09-12',
#   1427,
#   '2022-03-03 20:29:51.218746',
#   '2022-03-03 20:29:51.218749',
#   '98.12.197.249'),
#  (710,
#   'Sarah Wade',
#   'dwagner@example.org',
#   '90926 Megan Rapid Apt. 145\nSmithville, WI 38221',
#   'Santoschester',
#   'South Carolina',
#   'Estonia',
#   '639-333-8460x8772',
#   'Keep however cause Republican police near against story energy line.',
#   '1967-09-12',
#   1465,
#   '2022-03-03 20:29:51.219561',
#   '2022-03-03 20:29:51.219565',
#   '171.48.247.117'),
#  (711,
#   'Jennifer Jones',
#   'perezshane@example.com',
#   '6604 Cisneros Drives Suite 229\nEast Anthonytown, HI 21019',
#   'Kaylahaven',
#   'Kansas',
#   'Costa Rica',
#   '861.415.4687',
#   'Raise central happen difference across with person enter bad start '
#   'position.',
#   '1967-09-12',
#   2033,
#   '2022-03-03 20:29:51.220390',
#   '2022-03-03 20:29:51.220393',
#   '8.143.30.118'),
#  (712,
#   'Richard Haas',
#   'sholt@example.org',
#   '486 Thompson Valleys\nBoyerburgh, VA 91770',
#   'New Tylerport',
#   'Utah',
#   'Peru',
#   '+1-904-214-1010x334',
#   'Show security seem cultural outside reveal yourself foot to office.',
#   '1967-09-12',
#   1929,
#   '2022-03-03 20:29:51.221182',
#   '2022-03-03 20:29:51.221186',
#   '57.218.59.163'),
#  (713,
#   'Danielle Johnson',
#   'nathangraham@example.com',
#   'USNV Graham\nFPO AA 61660',
#   'Lake Danabury',
#   'Texas',
#   'Tunisia',
#   '+1-322-831-4528x55713',
#   'Bill most star alone doctor hold.',
#   '1967-09-12',
#   2075,
#   '2022-03-03 20:29:51.221905',
#   '2022-03-03 20:29:51.221908',
#   '174.39.14.146'),
#  (714,
#   'Lindsey Wright',
#   'brooke24@example.com',
#   '3418 Jeremy Court\nEast Stephenville, NV 79399',
#   'Port Brenda',
#   'Vermont',
#   'Micronesia',
#   '835.655.4939x16039',
#   'Save process allow possible drug camera eat well performance former.',
#   '1967-09-12',
#   2109,
#   '2022-03-03 20:29:51.222645',
#   '2022-03-03 20:29:51.222649',
#   '56.20.166.163'),
#  (715,
#   'Maria Griffin',
#   'daniel59@example.net',
#   '8420 Diana Mountain Suite 749\nWest Garyland, MO 43483',
#   'Ortizview',
#   'Iowa',
#   'Greece',
#   '265-826-5018',
#   'Bring marriage shake performance move collection customer hard pretty spend '
#   'fight.',
#   '1967-09-12',
#   2389,
#   '2022-03-03 20:29:51.223418',
#   '2022-03-03 20:29:51.223422',
#   '151.87.103.199'),
#  (716,
#   'Mr. Daniel Clark',
#   'johnsonchristina@example.com',
#   '38358 Kevin Inlet\nLake Jennifertown, NH 39670',
#   'Daviesville',
#   'Hawaii',
#   'Belarus',
#   '965-939-5544',
#   'Discover so friend beautiful when put benefit measure glass.',
#   '1967-09-12',
#   1340,
#   '2022-03-03 20:29:51.224258',
#   '2022-03-03 20:29:51.224262',
#   '41.12.12.246'),
#  (717,
#   'Derek Chen',
#   'fdyer@example.com',
#   '9473 Tony Points\nBlacktown, OH 33168',
#   'Luisfurt',
#   'Iowa',
#   'Bhutan',
#   '358.059.1055x59202',
#   'Hundred professional film wall per street bit two share.',
#   '1967-09-12',
#   1541,
#   '2022-03-03 20:29:51.225022',
#   '2022-03-03 20:29:51.225026',
#   '53.71.164.3'),
#  (718,
#   'Nicholas Robertson',
#   'moralesrichard@example.org',
#   '518 William Courts Apt. 692\nLake Laura, TN 27660',
#   'Brianburgh',
#   'North Dakota',
#   'Western Sahara',
#   '388-690-2367',
#   'Seek section many blood doctor southern occur.',
#   '1967-09-12',
#   1976,
#   '2022-03-03 20:29:51.225799',
#   '2022-03-03 20:29:51.225803',
#   '9.251.230.217'),
#  (719,
#   'Ryan Hernandez',
#   'alyssa70@example.org',
#   '58218 Smith Trafficway Suite 129\nLake Matthewview, OH 74695',
#   'Hollandport',
#   'Alaska',
#   'Venezuela',
#   '065-365-8945',
#   'Hand court attention even people attention modern nothing matter Democrat.',
#   '1967-09-12',
#   1816,
#   '2022-03-03 20:29:51.226580',
#   '2022-03-03 20:29:51.226584',
#   '36.170.112.87'),
#  (720,
#   'Natalie Chan',
#   'caleb99@example.org',
#   '12624 Fisher Drives Apt. 068\nDanielleview, NJ 98141',
#   'North Alyssaville',
#   'North Dakota',
#   'Portugal',
#   '(642)138-2038',
#   'Down home draw life energy they mean reflect since he safe population '
#   'common.',
#   '1967-09-12',
#   1807,
#   '2022-03-03 20:29:51.227356',
#   '2022-03-03 20:29:51.227360',
#   '20.220.253.203'),
#  (721,
#   'Robin Davis',
#   'abeasley@example.net',
#   '80330 Sosa Mountains\nJuantown, OR 09217',
#   'Martinberg',
#   'Montana',
#   'Argentina',
#   '432.094.8958x1525',
#   'State front outside middle start four wife various already nature office.',
#   '1967-09-12',
#   1999,
#   '2022-03-03 20:29:51.228147',
#   '2022-03-03 20:29:51.228150',
#   '98.210.139.134'),
#  (722,
#   'David Nichols',
#   'larry88@example.org',
#   '7313 Cunningham Mountain Suite 058\nWest Mary, GA 02316',
#   'North Rachel',
#   'California',
#   'Congo',
#   '898-517-6032x02326',
#   'Religious mouth traditional maybe civil history board clear everybody catch '
#   'audience.',
#   '1967-09-12',
#   2105,
#   '2022-03-03 20:29:51.228961',
#   '2022-03-03 20:29:51.228965',
#   '199.179.79.78'),
#  (723,
#   'Jeremy Winters',
#   'lisa53@example.net',
#   '14075 Brian Village\nNew Kathleen, SC 71592',
#   'East Josephport',
#   'Wyoming',
#   'San Marino',
#   '376.465.4718x350',
#   'Wall less soldier here perhaps our speech her shake design.',
#   '1967-09-12',
#   2189,
#   '2022-03-03 20:29:51.229680',
#   '2022-03-03 20:29:51.229683',
#   '153.238.39.68'),
#  (724,
#   'Lynn Harris',
#   'cynthiawhite@example.org',
#   'Unit 0847 Box 1927\nDPO AE 12364',
#   'Rodriguezchester',
#   'Louisiana',
#   'Niger',
#   '157.800.5864x732',
#   'For billion cold training ahead a entire term concern.',
#   '1967-09-12',
#   1977,
#   '2022-03-03 20:29:51.230357',
#   '2022-03-03 20:29:51.230361',
#   '192.245.198.148'),
#  (725,
#   'Eugene Huff',
#   'albert79@example.net',
#   '5828 Melinda Wall Apt. 589\nJohnsonbury, LA 80645',
#   'Lunamouth',
#   'Nebraska',
#   'Antarctica (the territory South of 60 deg S)',
#   '(355)162-5089x6215',
#   'Everyone fine reduce ability see available own would its new last grow.',
#   '1967-09-12',
#   2257,
#   '2022-03-03 20:29:51.231137',
#   '2022-03-03 20:29:51.231140',
#   '182.55.89.156'),
#  (726,
#   'Benjamin Kerr',
#   'wcastillo@example.org',
#   '585 Hancock Drive\nEast Kenneth, IL 09313',
#   'Thompsonview',
#   'Idaho',
#   'Gabon',
#   '001-360-608-9973x219',
#   'Happen plan scientist game prevent common some prepare standard outside.',
#   '1967-09-12',
#   2184,
#   '2022-03-03 20:29:51.231907',
#   '2022-03-03 20:29:51.231910',
#   '121.119.149.161'),
#  (727,
#   'Nicholas Velazquez',
#   'kochtaylor@example.net',
#   '705 Ryan Unions\nNorth Brent, OH 28851',
#   'Ashleyview',
#   'Tennessee',
#   'Burkina Faso',
#   '2204581912',
#   'Federal before different write public floor turn friend modern again '
#   'everyone quite.',
#   '1967-09-12',
#   1910,
#   '2022-03-03 20:29:51.232698',
#   '2022-03-03 20:29:51.232702',
#   '54.231.136.109'),
#  (728,
#   'Gabriella Preston',
#   'uallen@example.net',
#   '8055 Shawn Valley Apt. 258\nWest Dan, NC 89202',
#   'Lake Victoria',
#   'Nebraska',
#   'Guyana',
#   '+1-691-028-4681',
#   'Bill seat there opportunity law above toward wait head space win become '
#   'arm.',
#   '1967-09-12',
#   2492,
#   '2022-03-03 20:29:51.233447',
#   '2022-03-03 20:29:51.233450',
#   '205.209.38.189'),
#  (729,
#   'Brianna Williams',
#   'gphillips@example.org',
#   '097 Young Run Apt. 845\nMartinezbury, VT 89264',
#   'Carrville',
#   'Illinois',
#   'Heard Island and McDonald Islands',
#   '4186254672',
#   'Number face country never industry car career kitchen continue.',
#   '1967-09-12',
#   1515,
#   '2022-03-03 20:29:51.234275',
#   '2022-03-03 20:29:51.234279',
#   '197.139.217.99'),
#  (730,
#   'Charles Thomas',
#   'adam57@example.net',
#   '026 Freeman Groves Apt. 435\nSouth Michael, WA 91255',
#   'West Jason',
#   'Wisconsin',
#   'Pitcairn Islands',
#   '940-405-6666',
#   'Later smile officer international adult rate street rise price strong road '
#   'watch.',
#   '1967-09-12',
#   1320,
#   '2022-03-03 20:29:51.235030',
#   '2022-03-03 20:29:51.235034',
#   '191.120.114.77'),
#  (731,
#   'Kaitlyn Snow',
#   'hurstmonica@example.com',
#   '82043 Gibson Plaza\nJasonville, KS 24789',
#   'Harrisshire',
#   'Nebraska',
#   'Togo',
#   '962.757.5511x695',
#   'Send stage sound leave deal drop bed cost.',
#   '1967-09-12',
#   1904,
#   '2022-03-03 20:29:51.235879',
#   '2022-03-03 20:29:51.235883',
#   '163.21.77.58'),
#  (732,
#   'Debbie Lucero',
#   'brookefuentes@example.org',
#   '287 Savage Brook\nEricastad, NC 91713',
#   'New Gloria',
#   'Oklahoma',
#   'Sao Tome and Principe',
#   '647.001.7128x858',
#   'These whole fact film score right let guy better.',
#   '1967-09-12',
#   1343,
#   '2022-03-03 20:29:51.236704',
#   '2022-03-03 20:29:51.236708',
#   '109.135.251.4'),
#  (733,
#   'Leslie Lee',
#   'zmays@example.com',
#   '44866 Christina Trafficway Apt. 689\nSouth Cameronburgh, LA 88124',
#   'Tonyashire',
#   'South Carolina',
#   'Zimbabwe',
#   '113.786.4293x077',
#   'Director type idea thousand man dog expect treatment back figure power.',
#   '1967-09-12',
#   1168,
#   '2022-03-03 20:29:51.237472',
#   '2022-03-03 20:29:51.237476',
#   '66.95.99.208'),
#  (734,
#   'Catherine Bailey',
#   'riospatrick@example.net',
#   '52062 Bradley Divide\nMartinezfurt, CA 35150',
#   'Josephville',
#   'Missouri',
#   'Lebanon',
#   '3465298369',
#   'Training pass factor interest fear dog popular ever movement card anyone.',
#   '1967-09-12',
#   1968,
#   '2022-03-03 20:29:51.238308',
#   '2022-03-03 20:29:51.238312',
#   '139.183.176.141'),
#  (735,
#   'Bryce Brown',
#   'patrick52@example.net',
#   '38442 Derek Forest Apt. 961\nNew Willie, TN 46310',
#   'Harveyfort',
#   'Kansas',
#   'Montserrat',
#   '(809)635-4720x496',
#   'Thought hard owner campaign arrive follow experience follow no generation '
#   'discussion probably our.',
#   '1967-09-12',
#   2371,
#   '2022-03-03 20:29:51.239120',
#   '2022-03-03 20:29:51.239124',
#   '176.25.11.82'),
#  (736,
#   'Kristin Goodwin',
#   'yleonard@example.com',
#   '9358 Mcintyre Burgs\nMoralesland, SD 32317',
#   'East Lisaton',
#   'Iowa',
#   'Kiribati',
#   '3215468312',
#   'Nature line material approach prepare him environmental of look.',
#   '1967-09-12',
#   1812,
#   '2022-03-03 20:29:51.239910',
#   '2022-03-03 20:29:51.239914',
#   '1.172.56.149'),
#  (737,
#   'Nathan Robbins',
#   'morganwheeler@example.net',
#   '8487 Spencer Drives Suite 725\nVincentmouth, MI 75992',
#   'New Kevinshire',
#   'Tennessee',
#   'Afghanistan',
#   '730.426.7481',
#   'Himself skin responsibility south trouble cost later crime similar area.',
#   '1967-09-12',
#   1035,
#   '2022-03-03 20:29:51.240751',
#   '2022-03-03 20:29:51.240754',
#   '205.80.205.90'),
#  (738,
#   'Carl Clayton',
#   'natashacampbell@example.com',
#   '272 Melinda Pass\nWest Lauren, OH 49158',
#   'West Jose',
#   'Florida',
#   'Ghana',
#   '+1-223-915-4415',
#   'Bed generation speak memory spend table compare prevent discussion '
#   'information work.',
#   '1967-09-12',
#   1940,
#   '2022-03-03 20:29:51.241683',
#   '2022-03-03 20:29:51.241688',
#   '206.207.1.38'),
#  (739,
#   'Felicia Weaver',
#   'michaelmeadows@example.com',
#   '8464 Randall Flats Suite 988\nLake Ryan, NC 54334',
#   'Halebury',
#   'Idaho',
#   'British Virgin Islands',
#   '+1-702-128-8937',
#   'Itself movie record sea budget couple unit draw hotel quality.',
#   '1967-09-12',
#   1453,
#   '2022-03-03 20:29:51.242579',
#   '2022-03-03 20:29:51.242583',
#   '218.195.73.99'),
#  (740,
#   'Karen Booth',
#   'igoodwin@example.org',
#   '276 Perez Mountains\nPort Michael, SC 58843',
#   'North Stephanie',
#   'Washington',
#   'Cameroon',
#   '(580)326-2088',
#   'Nice staff chance big pay beyond include dream spring raise world machine.',
#   '1967-09-12',
#   2279,
#   '2022-03-03 20:29:51.243336',
#   '2022-03-03 20:29:51.243340',
#   '119.181.16.35'),
#  (741,
#   'Valerie Morgan',
#   'jperez@example.net',
#   'PSC 3069, Box 0029\nAPO AE 57907',
#   'Jacobland',
#   'Iowa',
#   'Israel',
#   '224-886-6290x40884',
#   'Where military include significant team enter rock give.',
#   '1967-09-12',
#   1740,
#   '2022-03-03 20:29:51.243930',
#   '2022-03-03 20:29:51.243934',
#   '151.126.89.106'),
#  (742,
#   'Gregory Casey',
#   'gene29@example.net',
#   '4745 Tracy Mountain\nLewisberg, VA 73274',
#   'Smithshire',
#   'Florida',
#   'Latvia',
#   '001-870-146-4028x288',
#   'Among land fund scene there including yet seek debate century dog.',
#   '1967-09-12',
#   1026,
#   '2022-03-03 20:29:51.244696',
#   '2022-03-03 20:29:51.244700',
#   '219.116.111.50'),
#  (743,
#   'Nicole Woods',
#   'katie72@example.net',
#   'Unit 6598 Box 1268\nDPO AE 71527',
#   'New Willie',
#   'Hawaii',
#   'Russian Federation',
#   '261-067-2900x532',
#   'Strong toward by movie save stop hour cell operation green.',
#   '1967-09-12',
#   1440,
#   '2022-03-03 20:29:51.245270',
#   '2022-03-03 20:29:51.245273',
#   '14.135.226.82'),
#  (744,
#   'Curtis Hernandez',
#   'scott54@example.net',
#   '36087 Elizabeth Haven Suite 556\nRamirezburgh, OH 62400',
#   'North Peter',
#   'Pennsylvania',
#   'United Kingdom',
#   '9081076655',
#   'Would action accept have attorney instead growth stage run toward enjoy as.',
#   '1967-09-12',
#   1016,
#   '2022-03-03 20:29:51.246019',
#   '2022-03-03 20:29:51.246023',
#   '154.108.152.119'),
#  (745,
#   'Julia Ashley',
#   'tammylang@example.org',
#   '26464 Douglas Plaza\nAliciaton, KS 84764',
#   'New Lisaburgh',
#   'Nevada',
#   'Paraguay',
#   '001-430-987-6779',
#   'Conference floor especially particularly still special something water art '
#   'region consider item.',
#   '1967-09-12',
#   2168,
#   '2022-03-03 20:29:51.246822',
#   '2022-03-03 20:29:51.246826',
#   '126.240.187.5'),
#  (746,
#   'Cody Arnold',
#   'robinpaul@example.org',
#   '51803 Lewis Center Suite 240\nBellchester, NM 71323',
#   'Smithfort',
#   'Connecticut',
#   'Ecuador',
#   '001-690-132-2266',
#   'Pull authority generation most inside difficult toward step thought.',
#   '1967-09-12',
#   2491,
#   '2022-03-03 20:29:51.247695',
#   '2022-03-03 20:29:51.247699',
#   '171.28.146.82'),
#  (747,
#   'Peter Larsen',
#   'mdonaldson@example.com',
#   'USS Garcia\nFPO AA 54326',
#   'Matthewmouth',
#   'Alaska',
#   'Albania',
#   '(605)900-1840x6866',
#   'Whole behind type understand baby admit.',
#   '1967-09-12',
#   1729,
#   '2022-03-03 20:29:51.248341',
#   '2022-03-03 20:29:51.248345',
#   '188.26.96.241'),
#  (748,
#   'William Thomas',
#   'todd14@example.net',
#   '1398 Freeman Heights Apt. 768\nNorth Amanda, GA 81597',
#   'Markview',
#   'Kansas',
#   'Singapore',
#   '(674)507-5091x93595',
#   'Name public moment focus treatment single small that read successful.',
#   '1967-09-12',
#   2493,
#   '2022-03-03 20:29:51.249483',
#   '2022-03-03 20:29:51.249488',
#   '65.136.0.25'),
#  (749,
#   'Christian Turner',
#   'graykimberly@example.org',
#   '4657 Beth Hill\nRodriguezshire, OH 98099',
#   'Newtonchester',
#   'Rhode Island',
#   'Saint Barthelemy',
#   '001-736-605-0780x1582',
#   'Cover save when would finally reality life movie.',
#   '1967-09-12',
#   1470,
#   '2022-03-03 20:29:51.250407',
#   '2022-03-03 20:29:51.250411',
#   '67.216.150.202'),
#  (750,
#   'Jesse Barnes',
#   'graveschristopher@example.com',
#   '450 Trevor Mall Apt. 069\nNorth Ryan, WY 82938',
#   'South Andrea',
#   'Ohio',
#   'Nigeria',
#   '001-001-220-6644x7079',
#   'Seven for issue bank control none bag go.',
#   '1967-09-12',
#   2252,
#   '2022-03-03 20:29:51.251263',
#   '2022-03-03 20:29:51.251268',
#   '173.191.251.239'),
#  (751,
#   'Nathaniel Thornton',
#   'josephflores@example.org',
#   '9140 Nicholas Meadow\nMatthewsmouth, WI 21884',
#   'North Heatherport',
#   'Georgia',
#   'Cook Islands',
#   '811-566-3561x2609',
#   'Most factor good reality agent doctor.',
#   '1967-09-12',
#   1448,
#   '2022-03-03 20:29:51.252133',
#   '2022-03-03 20:29:51.252137',
#   '85.188.55.52'),
#  (752,
#   'Samuel Acosta',
#   'wallsdalton@example.com',
#   '7188 Scott Island\nNew Anthonyfurt, KY 33673',
#   'Port Kimberly',
#   'Maryland',
#   'France',
#   '276.490.3236',
#   'Case fish wear board everything near final.',
#   '1967-09-12',
#   1529,
#   '2022-03-03 20:29:51.252915',
#   '2022-03-03 20:29:51.252919',
#   '71.2.247.6'),
#  (753,
#   'Adam Bryant',
#   'raymondthomas@example.org',
#   '516 Woods Route Suite 582\nAmberville, AR 17766',
#   'Lake Jasonfort',
#   'Delaware',
#   'Mongolia',
#   '(128)900-4297x0099',
#   'Behavior score weight go need rise fish.',
#   '1967-09-12',
#   2232,
#   '2022-03-03 20:29:51.253795',
#   '2022-03-03 20:29:51.253799',
#   '103.149.177.116'),
#  (754,
#   'Jessica Moyer',
#   'angelacline@example.com',
#   '030 John Land\nLake Juanburgh, AK 33358',
#   'West Jacob',
#   'Ohio',
#   'Israel',
#   '696.487.3660',
#   'Officer never candidate order car save important provide let contain.',
#   '1967-09-12',
#   2101,
#   '2022-03-03 20:29:51.254620',
#   '2022-03-03 20:29:51.254624',
#   '111.201.109.166'),
#  (755,
#   'Renee King',
#   'pcrosby@example.org',
#   '0787 Hartman Field\nEast Nicolestad, MD 79998',
#   'South Jerryshire',
#   'Michigan',
#   'Gibraltar',
#   '060-198-5293',
#   'Care consider act theory account after.',
#   '1967-09-12',
#   2485,
#   '2022-03-03 20:29:51.255409',
#   '2022-03-03 20:29:51.255413',
#   '183.167.187.28'),
#  (756,
#   'David Stone',
#   'gregorywright@example.com',
#   'Unit 2416 Box 6561\nDPO AE 80472',
#   'Mariabury',
#   'Ohio',
#   'Azerbaijan',
#   '+1-228-804-5836x3571',
#   'Attack nature science ability kid Mr goal clearly student interest window '
#   'able.',
#   '1967-09-12',
#   2205,
#   '2022-03-03 20:29:51.256069',
#   '2022-03-03 20:29:51.256073',
#   '10.127.120.182'),
#  (757,
#   'Stephen Case',
#   'lmendoza@example.org',
#   '70640 Peter Viaduct\nErinmouth, MN 83213',
#   'Smithville',
#   'Pennsylvania',
#   'Kazakhstan',
#   '001-836-147-1808x2327',
#   'Old office most way exactly idea boy practice pass wife.',
#   '1967-09-12',
#   1417,
#   '2022-03-03 20:29:51.256824',
#   '2022-03-03 20:29:51.256828',
#   '215.106.188.9'),
#  (758,
#   'Jackie Erickson',
#   'petermoses@example.com',
#   '895 Jeremiah Well Apt. 527\nRogersmouth, KS 58019',
#   'Matthewburgh',
#   'Delaware',
#   'New Zealand',
#   '+1-193-361-0398x060',
#   'Article participant he big various training physical reality data new '
#   'exactly me.',
#   '1967-09-12',
#   1533,
#   '2022-03-03 20:29:51.257671',
#   '2022-03-03 20:29:51.257675',
#   '113.221.82.70'),
#  (759,
#   'Adam Warner',
#   'antonioflowers@example.org',
#   '1564 Nicholson Haven Suite 477\nNorth Thomas, ME 18331',
#   'Newmanborough',
#   'Texas',
#   'Cyprus',
#   '865-385-3780x1319',
#   'Field budget far recent event assume yes item.',
#   '1967-09-12',
#   1415,
#   '2022-03-03 20:29:51.258525',
#   '2022-03-03 20:29:51.258528',
#   '221.142.48.84'),
#  (760,
#   'Gregory Lindsey',
#   'nicholas55@example.org',
#   '8045 White Highway Apt. 866\nJessicafort, DE 75481',
#   'Port Joelborough',
#   'Nevada',
#   'Tanzania',
#   '(482)457-7666',
#   'Stuff believe pass indicate should writer attack ready finish southern '
#   'quite.',
#   '1967-09-12',
#   2118,
#   '2022-03-03 20:29:51.259288',
#   '2022-03-03 20:29:51.259291',
#   '21.188.197.197'),
#  (761,
#   'Christopher Nelson',
#   'moranjames@example.com',
#   '246 Lauren Path Suite 422\nSantanafurt, WY 77770',
#   'Cohenview',
#   'California',
#   'Swaziland',
#   '055-438-5449',
#   'Hospital case care better good market truth.',
#   '1967-09-12',
#   1303,
#   '2022-03-03 20:29:51.260121',
#   '2022-03-03 20:29:51.260124',
#   '160.187.144.87'),
#  (762,
#   'Mathew Martinez',
#   'nicholas73@example.net',
#   '1230 Adrian Groves Suite 542\nSouth Jeffreyborough, VT 05652',
#   'Bethburgh',
#   'Tennessee',
#   'Costa Rica',
#   '001-631-107-1524x1654',
#   'Should rise child week third last north truth she open.',
#   '1967-09-12',
#   2184,
#   '2022-03-03 20:29:51.260855',
#   '2022-03-03 20:29:51.260859',
#   '200.43.116.60'),
#  (763,
#   'Daniel Soto',
#   'reynoldsjeffrey@example.org',
#   '4097 Julie Haven\nMarciamouth, ID 73040',
#   'Riveramouth',
#   'Colorado',
#   'Germany',
#   '+1-998-436-0294x9068',
#   'Seven official husband kid building however goal thank ready dinner '
#   'cultural.',
#   '1967-09-12',
#   1976,
#   '2022-03-03 20:29:51.261689',
#   '2022-03-03 20:29:51.261694',
#   '209.13.24.41'),
#  (764,
#   'Leah Evans',
#   'susan49@example.com',
#   '675 Michael Ville\nWest Kayla, NE 67852',
#   'Chelsealand',
#   'Maine',
#   'Panama',
#   '2337302221',
#   'Where team allow trade situation remain perhaps unit dream.',
#   '1967-09-12',
#   1480,
#   '2022-03-03 20:29:51.262397',
#   '2022-03-03 20:29:51.262400',
#   '20.86.172.87'),
#  (765,
#   'Michael Pope',
#   'woodsryan@example.com',
#   '3580 Sarah Bridge Suite 760\nSouth Julieborough, NE 32004',
#   'Marquezbury',
#   'Washington',
#   'Saint Barthelemy',
#   '(651)392-9401',
#   'Difficult another never much four low what.',
#   '1967-09-12',
#   1391,
#   '2022-03-03 20:29:51.263213',
#   '2022-03-03 20:29:51.263216',
#   '217.88.94.203'),
#  (766,
#   'Patrick Howell',
#   'ftaylor@example.net',
#   '85989 Hannah Ports Suite 146\nSouth Matthew, WI 98352',
#   'Kingmouth',
#   'Colorado',
#   'American Samoa',
#   '(184)631-9157x22684',
#   'Return form go none ability trouble go nature.',
#   '1967-09-12',
#   1661,
#   '2022-03-03 20:29:51.264004',
#   '2022-03-03 20:29:51.264007',
#   '128.49.225.11'),
#  (767,
#   'Matthew Long',
#   'agonzalez@example.net',
#   '18403 Benjamin Brooks\nLake Joseph, NJ 89870',
#   'New Sherritown',
#   'Minnesota',
#   'Algeria',
#   '581-881-0046x4717',
#   'Learn office street ball everyone color other play break could draw.',
#   '1967-09-12',
#   2014,
#   '2022-03-03 20:29:51.264734',
#   '2022-03-03 20:29:51.264737',
#   '210.51.55.81'),
#  (768,
#   'Michael Griffith',
#   'jamesperez@example.org',
#   '2599 Roth Meadows Suite 737\nMcgeeburgh, CA 26092',
#   'South Sharonburgh',
#   'New Mexico',
#   'Greece',
#   '864-284-5792x54462',
#   'Become figure bed garden firm hot space with.',
#   '1967-09-12',
#   1366,
#   '2022-03-03 20:29:51.265602',
#   '2022-03-03 20:29:51.265606',
#   '174.228.18.50'),
#  (769,
#   'Caroline Myers',
#   'reesemelissa@example.net',
#   'USCGC Wells\nFPO AE 72752',
#   'North Mary',
#   'Ohio',
#   'Costa Rica',
#   '530.327.9085x209',
#   'Or four number view report really fine organization.',
#   '1967-09-12',
#   2313,
#   '2022-03-03 20:29:51.266303',
#   '2022-03-03 20:29:51.266306',
#   '173.112.100.30'),
#  (770,
#   'Benjamin Anderson',
#   'tonya18@example.com',
#   '9515 Newman Underpass\nPort Jacqueline, WA 96083',
#   'Ryanville',
#   'Hawaii',
#   'Bouvet Island (Bouvetoya)',
#   '001-687-739-8646x0488',
#   'Say question huge star note opportunity election.',
#   '1967-09-12',
#   2328,
#   '2022-03-03 20:29:51.267053',
#   '2022-03-03 20:29:51.267057',
#   '154.190.35.108'),
#  (771,
#   'Jamie Adams',
#   'alan69@example.net',
#   '0216 Bowman Street\nEast Danielport, NY 36186',
#   'New Daniel',
#   'Iowa',
#   'Peru',
#   '+1-974-865-9312',
#   'Laugh give religious those student above economic system herself soldier '
#   'building.',
#   '1967-09-12',
#   1345,
#   '2022-03-03 20:29:51.267789',
#   '2022-03-03 20:29:51.267792',
#   '32.199.35.208'),
#  (772,
#   'Jennifer Wright',
#   'laurie85@example.net',
#   '915 Anderson Glen\nBeanshire, MD 19026',
#   'Joshuaborough',
#   'Louisiana',
#   'Gambia',
#   '(889)327-4628x5465',
#   'Into reveal religious key argue eye leg land Mrs project.',
#   '1967-09-12',
#   2499,
#   '2022-03-03 20:29:51.268574',
#   '2022-03-03 20:29:51.268578',
#   '113.67.89.87'),
#  (773,
#   'Cheyenne Alexander',
#   'harpersamuel@example.com',
#   '5317 Melissa Locks\nTonychester, OH 69212',
#   'South Donald',
#   'Utah',
#   'Saint Lucia',
#   '184-807-3306',
#   'Leg able country world performance two reduce member win note foot.',
#   '1967-09-12',
#   1790,
#   '2022-03-03 20:29:51.269367',
#   '2022-03-03 20:29:51.269370',
#   '126.72.211.30'),
#  (774,
#   'David Simmons',
#   'josemurphy@example.org',
#   '97784 Williams Squares Apt. 671\nRobertshaven, NC 71148',
#   'Jessicaburgh',
#   'Florida',
#   'Nauru',
#   '001-805-605-9358x33637',
#   'Sometimes several world bag information believe believe.',
#   '1967-09-12',
#   2146,
#   '2022-03-03 20:29:51.270209',
#   '2022-03-03 20:29:51.270212',
#   '170.129.48.67'),
#  (775,
#   'Rebecca Lane',
#   'javier10@example.org',
#   '76649 Fischer Junctions\nAndrewtown, WV 18035',
#   'Mcclureborough',
#   'Idaho',
#   'British Virgin Islands',
#   '(679)268-2957',
#   'Foot seat on force perform protect.',
#   '1967-09-12',
#   1822,
#   '2022-03-03 20:29:51.270965',
#   '2022-03-03 20:29:51.270969',
#   '180.55.99.148'),
#  (776,
#   'Denise Saunders',
#   'jennifer48@example.net',
#   '097 Monica Avenue\nBautistashire, MS 74879',
#   'Brockview',
#   'New Hampshire',
#   'France',
#   '563-180-7121',
#   'Artist wear huge attack them three look half apply miss.',
#   '1967-09-12',
#   1537,
#   '2022-03-03 20:29:51.271718',
#   '2022-03-03 20:29:51.271722',
#   '32.181.179.81'),
#  (777,
#   'Mary Jones',
#   'joannamoreno@example.org',
#   '9606 Nathaniel Light Suite 402\nPort Darinhaven, NY 37582',
#   'Nicholeview',
#   'Alaska',
#   'Angola',
#   '5371607814',
#   'These discuss spend themselves study life author American.',
#   '1967-09-12',
#   2150,
#   '2022-03-03 20:29:51.272525',
#   '2022-03-03 20:29:51.272528',
#   '186.63.132.248'),
#  (778,
#   'Dylan Perez',
#   'tpearson@example.org',
#   'Unit 8298 Box 7656\nDPO AE 94901',
#   'Michaelbury',
#   'Oklahoma',
#   'Uruguay',
#   '253.288.3907',
#   'Receive plan shake minute although natural own material.',
#   '1967-09-12',
#   1414,
#   '2022-03-03 20:29:51.273123',
#   '2022-03-03 20:29:51.273126',
#   '75.134.179.160'),
#  (779,
#   'Ryan Jackson',
#   'jcarter@example.com',
#   '464 Steve Green\nSouth Jenniferfort, KS 57863',
#   'West Brucehaven',
#   'Iowa',
#   'Jamaica',
#   '830.444.1868x642',
#   'Top information his house turn indicate wear win.',
#   '1967-09-12',
#   1054,
#   '2022-03-03 20:29:51.273912',
#   '2022-03-03 20:29:51.273917',
#   '75.198.41.222'),
#  (780,
#   'Bryan Romero',
#   'pattersonfrederick@example.com',
#   '88896 Green Mount\nAnnechester, SC 38781',
#   'Lake Johnny',
#   'North Carolina',
#   'Paraguay',
#   '001-129-394-9830',
#   'Then I standard full art drive term once role use onto foot office network.',
#   '1967-09-12',
#   1178,
#   '2022-03-03 20:29:51.274764',
#   '2022-03-03 20:29:51.274768',
#   '49.9.85.219'),
#  (781,
#   'Jessica Turner',
#   'heatherjones@example.net',
#   'Unit 7960 Box 3141\nDPO AE 71673',
#   'New Mark',
#   'Oklahoma',
#   'Iraq',
#   '095-498-6524',
#   'Girl rich none clear above certainly section relate by student rather.',
#   '1967-09-12',
#   1369,
#   '2022-03-03 20:29:51.275491',
#   '2022-03-03 20:29:51.275495',
#   '58.173.69.45'),
#  (782,
#   'Denise Wolf MD',
#   'elizabeth21@example.org',
#   '2362 Stephen Islands\nNew Jessemouth, ND 25105',
#   'Kimberlyfurt',
#   'Missouri',
#   'Tonga',
#   '001-704-727-3952x836',
#   'Whose life wall argue focus someone recognize necessary positive such '
#   'subject different.',
#   '1967-09-12',
#   1325,
#   '2022-03-03 20:29:51.276311',
#   '2022-03-03 20:29:51.276315',
#   '204.34.157.31'),
#  (783,
#   'Michael Moore',
#   'rfoster@example.org',
#   '2655 Houston Alley\nNelsontown, WA 81855',
#   'Jacksonville',
#   'Colorado',
#   'Guam',
#   '(275)765-1512',
#   'Claim save friend nearly trouble join society wait television shake '
#   'response center simple quite.',
#   '1967-09-12',
#   2194,
#   '2022-03-03 20:29:51.277155',
#   '2022-03-03 20:29:51.277159',
#   '73.168.33.13'),
#  (784,
#   'Lisa Walker',
#   'nicolewright@example.org',
#   '27932 Ryan Mountain Suite 858\nGoodmanside, AK 96603',
#   'Novakburgh',
#   'Wisconsin',
#   'Montserrat',
#   '813-080-8470',
#   'Successful morning time himself play page.',
#   '1967-09-12',
#   1615,
#   '2022-03-03 20:29:51.278030',
#   '2022-03-03 20:29:51.278033',
#   '28.13.19.48'),
#  (785,
#   'Carol Tyler',
#   'ysmith@example.net',
#   '855 Luis Rapids\nTiffanyberg, OK 76486',
#   'Traceyhaven',
#   'Delaware',
#   "Cote d'Ivoire",
#   '338-293-7844x1115',
#   'Pick a maybe especially glass enter away risk worry.',
#   '1967-09-12',
#   2080,
#   '2022-03-03 20:29:51.278765',
#   '2022-03-03 20:29:51.278769',
#   '55.240.217.53'),
#  (786,
#   'Jesse Park',
# ...
#   '1967-09-12',
#   1702,
#   '2022-03-03 20:29:51.423167',
#   '2022-03-03 20:29:51.423171',
#   '54.113.90.100'),
#  (956,
#   'Debra Wallace',
#   'davidellison@example.org',
#   'USS Mooney\nFPO AE 79795',
#   'Joneston',
#   'Oklahoma',
#   'United States Minor Outlying Islands',
#   '159-514-3908x8598',
#   'Case crime baby several better factor without.',
#   '1967-09-12',
#   1196,
#   '2022-03-03 20:29:51.423907',
#   '2022-03-03 20:29:51.423911',
#   '83.185.142.37'),
#  (957,
#   'Eric Harrison',
#   'pmann@example.org',
#   '0300 Melissa Loop\nNew Lauren, CA 98792',
#   'Phillipport',
#   'Alabama',
#   'Belgium',
#   '411.583.1065x79263',
#   'Test wear two indicate light morning according pretty street put most '
#   'offer.',
#   '1967-09-12',
#   1808,
#   '2022-03-03 20:29:51.424662',
#   '2022-03-03 20:29:51.424665',
#   '6.46.102.160'),
#  (958,
#   'Lauren Scott',
#   'beltranjessica@example.com',
#   '93558 Joseph Ports\nNew Kaitlynburgh, MA 61507',
#   'New Kimberly',
#   'Connecticut',
#   'British Virgin Islands',
#   '(295)106-5282x9042',
#   'Court tough impact agent rule writer organization leader why vote total '
#   'item enter.',
#   '1967-09-12',
#   2077,
#   '2022-03-03 20:29:51.425453',
#   '2022-03-03 20:29:51.425456',
#   '158.13.255.66'),
#  (959,
#   'Kent James',
#   'kevinflores@example.com',
#   '1769 Tucker Crossing Suite 269\nSouth Dawn, MS 09849',
#   'North Lindaburgh',
#   'New York',
#   'Zimbabwe',
#   '001-682-587-2543x54115',
#   'Baby small nation collection look follow.',
#   '1967-09-12',
#   1351,
#   '2022-03-03 20:29:51.426280',
#   '2022-03-03 20:29:51.426283',
#   '101.255.94.158'),
#  (960,
#   'Valerie Kelly',
#   'brett67@example.com',
#   '756 Ortega Union\nRobinchester, TX 56202',
#   'Port Erica',
#   'Montana',
#   'Spain',
#   '+1-201-069-0880x2038',
#   'Between activity style spend real note hospital bag focus reduce positive '
#   'usually.',
#   '1967-09-12',
#   1161,
#   '2022-03-03 20:29:51.427020',
#   '2022-03-03 20:29:51.427024',
#   '199.114.48.138'),
#  (961,
#   'Douglas Koch',
#   'huntjody@example.net',
#   '553 Wang Center Suite 044\nNorth Courtneyberg, OH 43182',
#   'South Elizabethside',
#   'Utah',
#   'Monaco',
#   '0691104023',
#   'Response tonight mean effort specific race.',
#   '1967-09-12',
#   1760,
#   '2022-03-03 20:29:51.427827',
#   '2022-03-03 20:29:51.427830',
#   '92.244.79.136'),
#  (962,
#   'Judith Ware',
#   'stephen11@example.net',
#   '897 Glenda Island Apt. 319\nGabriellemouth, IL 73005',
#   'West Cheryl',
#   'Nebraska',
#   'Uruguay',
#   '7818239565',
#   'Radio during ago real official pull.',
#   '1967-09-12',
#   1579,
#   '2022-03-03 20:29:51.428553',
#   '2022-03-03 20:29:51.428556',
#   '168.65.236.78'),
#  (963,
#   'Brandi Thompson',
#   'walter94@example.com',
#   '439 Pierce Light\nJeffreyland, PA 50293',
#   'Port Jason',
#   'Nevada',
#   'Cocos (Keeling) Islands',
#   '597.140.7674',
#   'Space nothing understand do majority again Congress cost difficult popular '
#   'citizen.',
#   '1967-09-12',
#   1470,
#   '2022-03-03 20:29:51.429290',
#   '2022-03-03 20:29:51.429294',
#   '169.151.20.106'),
#  (964,
#   'Jennifer Robinson',
#   'robertsullivan@example.org',
#   '65520 Erica Canyon Suite 117\nBonnietown, RI 67214',
#   'North Isaac',
#   'California',
#   'Macao',
#   '7252058272',
#   'Smile nation where apply wait sport rather.',
#   '1967-09-12',
#   1540,
#   '2022-03-03 20:29:51.430081',
#   '2022-03-03 20:29:51.430084',
#   '125.96.214.242'),
#  (965,
#   'Steven Stewart',
#   'michaelorozco@example.com',
#   '635 Peter Ports Suite 469\nAndrewbury, KY 81894',
#   'East Beverlyside',
#   'Iowa',
#   'Hungary',
#   '+1-360-751-1804x60758',
#   'Simple ask issue give easy note voice reduce ago section military also.',
#   '1967-09-12',
#   1308,
#   '2022-03-03 20:29:51.430877',
#   '2022-03-03 20:29:51.430881',
#   '191.140.211.245'),
#  (966,
#   'David Ortiz',
#   'cprice@example.com',
#   '589 Mendoza Parkways\nWest Mariah, UT 69737',
#   'Port Lisa',
#   'Hawaii',
#   'Tokelau',
#   '264-580-4906',
#   'His country very several soldier economy international cold.',
#   '1967-09-12',
#   1101,
#   '2022-03-03 20:29:51.431628',
#   '2022-03-03 20:29:51.431632',
#   '189.213.48.50'),
#  (967,
#   'Heather Ward',
#   'williamsmichaela@example.com',
#   '3223 Jordan Loop\nNew Trevortown, IN 18556',
#   'Normanhaven',
#   'Georgia',
#   'Turkey',
#   '028.621.8705',
#   'South list training war western artist executive son enjoy focus '
#   'everything.',
#   '1967-09-12',
#   2286,
#   '2022-03-03 20:29:51.432450',
#   '2022-03-03 20:29:51.432454',
#   '89.162.87.106'),
#  (968,
#   'Ronald Andersen',
#   'ecook@example.net',
#   '360 Greene Expressway\nKeithfort, RI 70372',
#   'Williamsontown',
#   'Rhode Island',
#   'Venezuela',
#   '602-641-5558',
#   'Election rise firm certain them type discover body involve trouble specific '
#   'area as.',
#   '1967-09-12',
#   1444,
#   '2022-03-03 20:29:51.433260',
#   '2022-03-03 20:29:51.433264',
#   '223.217.18.175'),
#  (969,
#   'Kimberly Zuniga',
#   'npatterson@example.com',
#   '5335 Timothy Islands Apt. 963\nSouth Craigview, MT 90980',
#   'Kingbury',
#   'Hawaii',
#   'Palau',
#   '(808)819-4551',
#   'Focus kind worry staff should training.',
#   '1967-09-12',
#   1112,
#   '2022-03-03 20:29:51.434112',
#   '2022-03-03 20:29:51.434116',
#   '106.52.240.91'),
#  (970,
#   'Nicole Donovan DVM',
#   'scarlson@example.com',
#   '00383 Pamela Route Suite 979\nMichaelville, ND 47152',
#   'Greenton',
#   'Indiana',
#   'Ethiopia',
#   '746.593.6126x2519',
#   'School a player tend cut professional happen large serious.',
#   '1967-09-12',
#   2450,
#   '2022-03-03 20:29:51.434892',
#   '2022-03-03 20:29:51.434895',
#   '193.51.231.142'),
#  (971,
#   'Janet Hart',
#   'sjohnson@example.com',
#   '1315 Bradley Shores Apt. 591\nSouth Debramouth, MD 65776',
#   'Glennton',
#   'Utah',
#   'Moldova',
#   '3472644680',
#   'Chair program treat director course compare they history international '
#   'marriage.',
#   '1967-09-12',
#   1875,
#   '2022-03-03 20:29:51.435704',
#   '2022-03-03 20:29:51.435708',
#   '152.153.212.173'),
#  (972,
#   'April Fleming',
#   'jennifer80@example.net',
#   '0057 Dawson Lake Apt. 757\nStephanieberg, IN 73368',
#   'South Wandachester',
#   'Illinois',
#   'Bahrain',
#   '+1-227-640-3243x7253',
#   'So not capital continue and push.',
#   '1967-09-12',
#   1696,
#   '2022-03-03 20:29:51.436473',
#   '2022-03-03 20:29:51.436476',
#   '40.15.64.167'),
#  (973,
#   'Angel Thompson',
#   'brendamartin@example.com',
#   'PSC 6972, Box 4047\nAPO AE 25487',
#   'New Brittany',
#   'Kentucky',
#   'Kenya',
#   '788.937.5519x83520',
#   'Candidate would ten weight money first treatment line purpose mouth.',
#   '1967-09-12',
#   2351,
#   '2022-03-03 20:29:51.437135',
#   '2022-03-03 20:29:51.437138',
#   '100.212.67.45'),
#  (974,
#   'Leslie Vaughan PhD',
#   'kimberly43@example.org',
#   'PSC 5113, Box 4061\nAPO AA 14173',
#   'Lake Kristin',
#   'North Carolina',
#   'American Samoa',
#   '+1-448-533-9539x7861',
#   'Land near before offer could style color particularly bank claim wonder '
#   'nice city.',
#   '1967-09-12',
#   1693,
#   '2022-03-03 20:29:51.437711',
#   '2022-03-03 20:29:51.437714',
#   '122.146.238.128'),
#  (975,
#   'Ralph Thompson',
#   'hhunter@example.org',
#   '697 Joshua Hollow Suite 615\nWest Josephchester, NV 53192',
#   'Port James',
#   'Alabama',
#   'Bangladesh',
#   '521-236-6143',
#   'World memory beat material save week kid.',
#   '1967-09-12',
#   2241,
#   '2022-03-03 20:29:51.438444',
#   '2022-03-03 20:29:51.438447',
#   '7.209.128.59'),
#  (976,
#   'Tanya White',
#   'cortezcarol@example.com',
#   'PSC 0194, Box 2833\nAPO AA 35080',
#   'Bryantton',
#   'Alabama',
#   'Mauritania',
#   '540-551-9380',
#   'Hand theory begin difficult power under people especially act success '
#   'probably experience.',
#   '1967-09-12',
#   1148,
#   '2022-03-03 20:29:51.439127',
#   '2022-03-03 20:29:51.439130',
#   '163.153.127.7'),
#  (977,
#   'Alyssa Fox',
#   'mnorton@example.net',
#   '59590 Taylor Route Apt. 947\nPort Maryberg, NY 58316',
#   'Jenkinsstad',
#   'Tennessee',
#   'San Marino',
#   '(294)925-8227',
#   'Child person administration suffer education action husband down.',
#   '1967-09-12',
#   2133,
#   '2022-03-03 20:29:51.440011',
#   '2022-03-03 20:29:51.440015',
#   '210.150.69.105'),
#  (978,
#   'Linda Young',
#   'carl74@example.org',
#   '331 Young Keys\nNorth Christopher, ME 24038',
#   'Zunigafurt',
#   'Florida',
#   'Liechtenstein',
#   '735.689.2946',
#   'Early general itself church what education save shoulder hear only more '
#   'example.',
#   '1967-09-12',
#   1380,
#   '2022-03-03 20:29:51.440763',
#   '2022-03-03 20:29:51.440767',
#   '118.24.133.231'),
#  (979,
#   'Sharon Brown',
#   'qjohnson@example.org',
#   'Unit 4041 Box 4403\nDPO AA 90643',
#   'Bauerchester',
#   'Kansas',
#   'Madagascar',
#   '430.914.6645x5865',
#   'Six away old better majority may.',
#   '1967-09-12',
#   2446,
#   '2022-03-03 20:29:51.441376',
#   '2022-03-03 20:29:51.441379',
#   '200.224.12.43'),
#  (980,
#   'Heather Thompson',
#   'phillipsadam@example.com',
#   '66269 Charles Oval\nCampbellchester, MT 04020',
#   'Marshallview',
#   'South Carolina',
#   'Western Sahara',
#   '025.456.1820x061',
#   'Push still nice similar education peace lot leader.',
#   '1967-09-12',
#   1333,
#   '2022-03-03 20:29:51.442220',
#   '2022-03-03 20:29:51.442224',
#   '34.211.229.158'),
#  (981,
#   'Paige Romero',
#   'lhensley@example.net',
#   '2055 Sarah Shores\nJonathonfurt, NM 93024',
#   'East Davidmouth',
#   'Wyoming',
#   'Burkina Faso',
#   '449.079.1258',
#   'Painting ask class often among wrong item almost management phone.',
#   '1967-09-12',
#   2153,
#   '2022-03-03 20:29:51.442936',
#   '2022-03-03 20:29:51.442939',
#   '113.69.37.99'),
#  (982,
#   'Frederick Shelton',
#   'rgrant@example.com',
#   '6368 Davidson Creek Apt. 980\nWest Danielleport, SD 93975',
#   'East Scott',
#   'Nevada',
#   'Azerbaijan',
#   '389-387-7901',
#   'Maybe production performance seem candidate up ahead task near.',
#   '1967-09-12',
#   1484,
#   '2022-03-03 20:29:51.443714',
#   '2022-03-03 20:29:51.443718',
#   '129.250.149.37'),
#  (983,
#   'Joshua Ortega',
#   'grahamjoseph@example.net',
#   '549 Owen Unions Suite 812\nPort Justin, AL 77842',
#   'Timothyland',
#   'Wyoming',
#   'Swaziland',
#   '5882750627',
#   'Hear agency let guy pass south few up glass while bank speak.',
#   '1967-09-12',
#   1413,
#   '2022-03-03 20:29:51.444523',
#   '2022-03-03 20:29:51.444527',
#   '190.66.145.208'),
#  (984,
#   'Mary Kelley',
#   'janice93@example.com',
#   '4488 Hull Drives Suite 869\nPort Samantha, NM 52882',
#   'New Eric',
#   'Georgia',
#   'Netherlands',
#   '001-619-108-3800',
#   'Game ball man only move center wife.',
#   '1967-09-12',
#   2087,
#   '2022-03-03 20:29:51.445269',
#   '2022-03-03 20:29:51.445272',
#   '52.197.198.208'),
#  (985,
#   'Jacob Tucker',
#   'tcarroll@example.com',
#   '998 Burns Cape Suite 108\nSimmonsside, WA 32131',
#   'Amyborough',
#   'Illinois',
#   'Gabon',
#   '430-030-7239x76603',
#   'Accept your exist usually Democrat say town television back value approach '
#   'institution.',
#   '1967-09-12',
#   1370,
#   '2022-03-03 20:29:51.446071',
#   '2022-03-03 20:29:51.446075',
#   '52.126.104.154'),
#  (986,
#   'Timothy Atkins',
#   'katherinebrock@example.net',
#   '806 Alan Oval\nPort Carolshire, MI 70647',
#   'Jasonfurt',
#   'Florida',
#   'Libyan Arab Jamahiriya',
#   '636.285.2862',
#   'Door week red hold prove sort history.',
#   '1967-09-12',
#   1908,
#   '2022-03-03 20:29:51.446853',
#   '2022-03-03 20:29:51.446857',
#   '88.36.221.140'),
#  (987,
#   'Raymond Stevens',
#   'diane61@example.com',
#   '991 Jackie Vista Apt. 569\nTorreston, WI 83901',
#   'Leetown',
#   'Vermont',
#   'United States Minor Outlying Islands',
#   '3388927032',
#   'Create arm agent political include owner product difficult position feeling '
#   'region remain beyond.',
#   '1967-09-12',
#   2083,
#   '2022-03-03 20:29:51.447624',
#   '2022-03-03 20:29:51.447628',
#   '86.86.106.86'),
#  (988,
#   'Gwendolyn Kramer',
#   'melaniepowers@example.com',
#   '4823 Spencer Prairie\nNorth Jeremy, OR 26903',
#   'Port Desiree',
#   'Vermont',
#   'Tajikistan',
#   '191.659.7132x0089',
#   'She idea system affect various that.',
#   '1967-09-12',
#   2342,
#   '2022-03-03 20:29:51.448425',
#   '2022-03-03 20:29:51.448428',
#   '3.183.76.213'),
#  (989,
#   'Jeffrey Keith',
#   'pbrady@example.com',
#   '597 Deanna Avenue Apt. 454\nLake Stephanie, CT 61311',
#   'North Madisonbury',
#   'Connecticut',
#   'Kiribati',
#   '+1-734-826-5977x28893',
#   'New side shake person turn blue success everyone apply body billion your.',
#   '1967-09-12',
#   1217,
#   '2022-03-03 20:29:51.449211',
#   '2022-03-03 20:29:51.449215',
#   '48.186.87.106'),
#  (990,
#   'Amanda Thomas',
#   'anthony78@example.com',
#   '8176 Ruiz Hills Apt. 429\nWest Stephaniebury, ME 47739',
#   'Swansonland',
#   'New Hampshire',
#   'Greenland',
#   '(775)589-6503',
#   'Data gas anyone beyond wall computer world.',
#   '1967-09-12',
#   2154,
#   '2022-03-03 20:29:51.450021',
#   '2022-03-03 20:29:51.450025',
#   '166.214.92.116'),
#  (991,
#   'Alicia Mendoza',
#   'andrew37@example.net',
#   '25478 Francisco Curve Apt. 374\nJaredhaven, NM 92122',
#   'Port Debramouth',
#   'Missouri',
#   'United Arab Emirates',
#   '(762)667-7264x17478',
#   'Model capital throughout sound professional none too just.',
#   '1967-09-12',
#   1584,
#   '2022-03-03 20:29:51.450766',
#   '2022-03-03 20:29:51.450769',
#   '124.96.190.25'),
#  (992,
#   'Diamond Graham',
#   'cbyrd@example.com',
#   '25720 Darryl Spring Suite 635\nNew Lorettahaven, NY 75104',
#   'East Todd',
#   'Georgia',
#   'Guernsey',
#   '+1-740-407-2173x9727',
#   'Best simple key idea significant foreign dark.',
#   '1967-09-12',
#   1738,
#   '2022-03-03 20:29:51.451527',
#   '2022-03-03 20:29:51.451531',
#   '134.165.229.58'),
#  (993,
#   'David Gross',
#   'xbrown@example.org',
#   '70922 Karla Knolls\nNew Dillon, MI 40434',
#   'New Ashleyland',
#   'Florida',
#   'Maldives',
#   '466.743.4784',
#   'Responsibility it bring add table fact.',
#   '1967-09-12',
#   1074,
#   '2022-03-03 20:29:51.452263',
#   '2022-03-03 20:29:51.452266',
#   '12.59.214.207'),
#  (994,
#   'Jason Jennings',
#   'christophermartin@example.org',
#   '26273 Wright Heights\nWest Stephen, NM 95134',
#   'East Brittany',
#   'Missouri',
#   'Egypt',
#   '466.739.9834',
#   'Boy card statement bit choose risk.',
#   '1967-09-12',
#   1003,
#   '2022-03-03 20:29:51.453068',
#   '2022-03-03 20:29:51.453072',
#   '176.60.185.102'),
#  (995,
#   'Kim Bryant',
#   'jaywalker@example.com',
#   '15875 Austin Fords Suite 028\nBeckyville, MI 54205',
#   'Owenport',
#   'Missouri',
#   'Georgia',
#   '395-838-3212x036',
#   'Newspaper cover national reveal sea thus.',
#   '1967-09-12',
#   1133,
#   '2022-03-03 20:29:51.453909',
#   '2022-03-03 20:29:51.453912',
#   '142.35.81.5'),
#  (996,
#   'Stephanie Andrews',
#   'chelsea20@example.net',
#   '457 Gonzalez Hollow Apt. 001\nJeffreyton, GA 36471',
#   'Raymondton',
#   'Utah',
#   'Falkland Islands (Malvinas)',
#   '4821550484',
#   'Voice food national pull expert force newspaper.',
#   '1967-09-12',
#   1261,
#   '2022-03-03 20:29:51.454654',
#   '2022-03-03 20:29:51.454657',
#   '186.55.99.100'),
#  (997,
#   'Emily Ramirez',
#   'reevesmichael@example.net',
#   '9471 Cain Corners\nJohnstad, KY 05512',
#   'West Brianhaven',
#   'Maryland',
#   'Haiti',
#   '069-887-2388',
#   'Nature information per to trouble value.',
#   '1967-09-12',
#   2470,
#   '2022-03-03 20:29:51.455460',
#   '2022-03-03 20:29:51.455463',
#   '113.86.123.181'),
#  (998,
#   'Margaret Gonzalez',
#   'james79@example.org',
#   '6112 Shannon Ridges Suite 423\nBradleystad, NM 65436',
#   'Lake Davidville',
#   'Kansas',
#   'South Georgia and the South Sandwich Islands',
#   '899.972.0786',
#   'Guy garden find wait mother practice range hear through space.',
#   '1967-09-12',
#   1439,
#   '2022-03-03 20:29:51.456182',
#   '2022-03-03 20:29:51.456186',
#   '113.162.69.217'),
#  (999,
#   'Katherine Rose',
#   'staffordoscar@example.com',
#   '64239 Philip Groves Apt. 433\nWest William, TN 23310',
#   'West Charlesport',
#   'South Dakota',
#   'Pitcairn Islands',
#   '+1-164-468-3241x5078',
#   'Form opportunity personal scientist scientist expert center social hospital '
#   'newspaper agreement position article.',
#   '1967-09-12',
#   2420,
#   '2022-03-03 20:29:51.457004',
#   '2022-03-03 20:29:51.457008',
#   '136.206.235.102'),
#  (1000,
#   'Wendy Bentley',
#   'vwilliams@example.net',
#   '38448 Williams Garden\nAdrienneland, OK 80904',
#   'Port Kristinton',
#   'Oklahoma',
#   'Slovenia',
#   '107.101.7745',
#   'Try level top part give often room commercial near campaign clearly.',
#   '1967-09-12',
#   2391,
#   '2022-03-03 20:29:51.457764',
#   '2022-03-03 20:29:51.457767',
#   '118.28.91.238')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT name, heatmap FROM people 
                            WHERE heatmap > 1500
                            LIMIT 20"""

myCursor.execute( selectStatement )
results = myCursor.fetchall()
print(results)
# Out:
# [('Anna Price', 2414), ('Kathy Jenkins', 2355), ('Michael Taylor', 2414), ('Jamie Paul', 2160), ('Stephanie Odom', 2474), ('Leslie Webb', 1543), ('Bryan Mack', 1633), ('Jeff Diaz', 2119), ('Stacy Stephens', 2109), ('Mrs. Chelsea Mcneil', 2449), ('Phillip Carney', 2386), ('Anthony Moss', 2429), ('Benjamin Burgess', 1597), ('Stephanie Rodriguez', 1660), ('Kristin Martin', 2232), ('Anthony James II', 1834), ('Carol Moyer', 1670), ('Kelly Jones', 1617), ('Shannon Russo', 1745), ('Linda Hicks', 2009)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
